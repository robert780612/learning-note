# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Beats

# %%
t = np.linspace(0,10,1000)
omega1 = 10
omega2 = 12
y1 = np.cos(omega1*t)
y2 = np.cos(omega2*t)

# %%
plt.plot(t,y1+y2)
plt.plot([pi/2,pi/2],[-1.5,2],'r')
plt.plot(2*np.array([pi/2,pi/2]),[-1.5,2],'r')
plt.plot(3*np.array([pi/2,pi/2]),[-1.5,2],'r')

# %%
2*np.array([0,1,2])
# Out:
# array([0, 2, 4])
